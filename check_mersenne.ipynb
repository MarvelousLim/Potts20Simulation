# %%
import numpy as np, matplotlib.pyplot as plt

# %%
with open("Potts20Simulation/MersenneTwisterCheckSeed0.txt") as f:
    for line in f:
        data = np.fromiter(map(float, line.split()), dtype=np.float)
data
# Out:
# array([0.0840399, 0.279608 , 0.538754 , ..., 0.0121025, 0.56826  ,
#        0.706353 ])

# %%
plt.hist(data)
plt.show()

# %%
plt.plot(data, 'o')
plt.show()

# %%
def acf(x, length=20):
    return numpy.array([1]+[numpy.corrcoef(x[:-i], x[i:])[0,1]  \
        for i in range(1, length)])
plt.plot(acf(data, length=100))
plt.show()
