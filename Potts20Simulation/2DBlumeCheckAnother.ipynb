# %%
import numpy as np, matplotlib.pyplot as plt
from collections import OrderedDict as od
from scipy.special import comb as C
from scipy.stats import linregress
from statistics import median
from scipy.optimize import fminbound
import json
import itertools
from tqdm.notebook import tqdm
from multiprocess import Pool
from magic_functions import calc_hc_tpl

# %%
def get_entropy_from_culling_factor_v2(c):
    S = od()
    sn = 0
    for E in c:
        S[E] = np.log(c[E])
        S[E] += sn
        sn += np.log(1 - c[E])
    return S

def get_entropy_from_culling_factor_with_heat_v2(c):
    S = od()
    sn = 0
    for E in c:
        S[E] = np.log(c[E])
        S[E] += sn
        sn += np.log(1 - c[E])
    return S

# %%
def read_files_v2(parameters, prefix = None):
    q=parameters["q"];
    L=parameters["L"];
    R=parameters["R"];
    D=parameters["D"];
    nSteps=parameters["nSteps"];
    seed=parameters["seed"];
    heat=parameters["heat"];
    N = L * L;
    name = ".{}/2DBlume{}_q{}_D{}_N{}_R{}_nSteps{}_run{}X.txt".format(prefix, "Heating" * heat, q, "{0:07.6f}".format(D), N, R, nSteps, seed)
    print(name)
    culling_factor = od()
    print(N, R, nSteps, heat)
    with open(name) as f:
        for line in f:
            E, c = map(float, line.split())
            culling_factor[E] = c
    parameters["culling_factor"] = culling_factor
    if not heat:
        parameters["S"] = get_entropy_from_culling_factor_v2(culling_factor)
    else:
        parameters["S"] = get_entropy_from_culling_factor_with_heat_v2(culling_factor)
    
    return parameters


def stitch_S(heat, cool):
    #not infinite values
    niv = sorted( list({E for E, S in heat["S"].items() if not np.isinf(S)} &
                       {E for E, S in cool["S"].items() if not np.isinf(S)}) )
    #chosen not infinite values
    cniv = niv[len(niv) // 3 : 2 * len(niv) // 3]
    #print(cniv)
    shift = 0
    count = 0
    for E in cniv:
        shift += heat["S"][E] - cool["S"][E]
        count += 1
    shift /= count

    result = od()
    for E in cool["S"]:
        if E < median(cniv):
            result[E] = cool["S"][E]
    for E in heat["S"]:
        if E >= median(cniv):
            result[E] = heat["S"][E] - shift
    return {"S": result, "L": heat["L"], "D": heat["D"]}


def read_tuple_files(tpl, prefix=None):
    if tpl[1]["heat"]:
        cool = read_files_v2(tpl[0], prefix)
        heat = read_files_v2(tpl[1], prefix)
        return {
            "cool": cool,
            "heat": heat,
            "stitched": stitch_S(heat, cool)
        }

# %%
#L_list = [8, 12, 16, 20, 24, 32, 48, 64, 96]
D = 1.99
L = 8
cool, heat = [{
    "q": 3,
    "D": D,
    "L": L,
    "R" : 131072,
    "nSteps" : 10,
    "seed" : 0,
    "heat": False
}], [{
    "q": 3,
    "D": D,
    "L": L,
    "R" : 131072,
    "nSteps" : 10,
    "seed" : 0,
    "heat": True
}]

parameters = []
for x in zip(cool, heat):
    parameters.append(read_tuple_files(x, '/datasets/2DBlumeOld(FloatEnergy)'))
# Out:
# ./datasets/2DBlumeOld(FloatEnergy)/2DBlume_q3_D1.990000_N64_R131072_nSteps10_run0X.txt
# 64 131072 10 False
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys
# ./datasets/2DBlumeOld(FloatEnergy)/2DBlumeHeating_q3_D1.990000_N64_R131072_nSteps10_run0X.txt
# 64 131072 10 True
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()

# %%
parametersAR = []
for x in zip(cool, heat):
    parametersAR.append(read_tuple_files(x, '/datasets'))
# Out:
# ./datasets/2DBlume_q3_D1.990000_N64_R131072_nSteps10_run0X.txt
# 64 131072 10 False
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log
#   import sys
# ./datasets/2DBlumeHeating_q3_D1.990000_N64_R131072_nSteps10_run0X.txt
# 64 131072 10 True
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: RuntimeWarning: divide by zero encountered in log
#   app.launch_new_instance()

# %%
#coolAR = read_files_v2(cool[0], '/AR_datasets/datasets')

# %%
plt.figure(figsize=(16, 9))

i = 0
heat, cool = parameters[i]["heat"], parameters[i]["cool"]

plt.plot([E for E in cool["culling_factor"]], [S for E, S in cool["culling_factor"].items()]
         , 'o', label="L={}; cool".format(cool["L"]))
plt.plot([E for E in heat["culling_factor"]], [S for E, S in heat["culling_factor"].items()]
         , 'o', label="L={}; heat".format(heat["L"]))

plt.ylabel("$culling_factor(E)$")
plt.xlabel("E")
#plt.ylim([-200, -175])
#plt.xlim([-216, -175])
#plt.xlim([-2000, 2000])
plt.legend()
plt.grid()
#plt.savefig("./culling_factor_D{}_L{}.png".format(heat["D"], heat["L"]))

# %%
plt.figure(figsize=(16, 9))

i = 0
heat, cool = parametersAR[i]["heat"], parametersAR[i]["cool"]

plt.plot([E for E in cool["culling_factor"]], [S for E, S in cool["culling_factor"].items()]
         , 'o', label="L={}; cool".format(cool["L"]))
plt.plot([E for E in heat["culling_factor"]], [S for E, S in heat["culling_factor"].items()]
         , 'o', label="L={}; heat".format(heat["L"]))

plt.ylabel("$culling_factor(E)$")
plt.xlabel("E")
#plt.ylim([-200, -175])
#plt.xlim([-216, -175])
#plt.xlim([-2000, 2000])
plt.legend()
plt.grid()
#plt.savefig("./culling_factor_D{}_L{}.png".format(heat["D"], heat["L"]))

# %%
plt.figure(figsize=(16, 9))

i = 0
heat, cool, st = parameters[i]["heat"], parameters[i]["cool"], parameters[i]["stitched"]

plt.plot([E for E in cool["S"]], [S for E, S in cool["S"].items()]
         , 'o', label="L={}; cool".format(cool["L"]))
plt.plot([E for E in heat["S"]], [S for E, S in heat["S"].items()]
         , 'o', label="L={}; heat".format(heat["L"]))
plt.plot([E for E in st["S"]], [S - 5 for E, S in st["S"].items()]
         , 'o', label="L={}; heat".format(heat["L"]), markersize=0.5)

plt.ylabel("$S(E)$")
plt.xlabel("E")
#plt.ylim([-20, 0])
#plt.xlim([1200, 1300])
#plt.xlim([-2000, 2000])
plt.legend()
plt.grid()
#plt.savefig("./culling_factor_D{}_L{}.png".format(heat["D"], heat["L"]))

# %%
plt.figure(figsize=(16, 9))

i = 0
heat, cool, st = parametersAR[i]["heat"], parametersAR[i]["cool"], parametersAR[i]["stitched"]

#plt.plot([E for E in cool["S"]], [S for E, S in cool["S"].items()]
#         , 'o', label="L={}; cool".format(cool["L"]), markersize=0.5)
#plt.plot([E for E in heat["S"]], [S for E, S in heat["S"].items()]
#         , 'o', label="L={}; heat".format(heat["L"]), markersize=0.5)
plt.plot([E for E in st["S"]], [S - 5 for E, S in st["S"].items()]
         , 'o', label="L={}; heat".format(heat["L"]), markersize=0.5)

plt.ylabel("$S(E)$")
plt.xlabel("E")
#plt.ylim([-20, 0])
#plt.xlim([1200, 1300])
#plt.xlim([-2000, 2000])
plt.legend()
plt.grid()
#plt.savefig("./culling_factor_D{}_L{}.png".format(heat["D"], heat["L"]))

# %%
plt.figure(figsize=(16, 9))

i = 0
a = -1000
b = 2000

st = parameters[i]["stitched"]

plt.plot([E for E in st["S"] if a < E and E < b], [S for E, S in st["S"].items() if a < E and E < b]
         , 'o', label="L={}; heat".format(heat["L"]), markersize=0.5)

st =parametersAR[i]["stitched"]

plt.plot([E for E in st["S"]if a < E and E < b], [S - 5 for E, S in st["S"].items() if a < E and E < b]
         , 'o', label="L={}; heat".format(heat["L"]), markersize=0.5)

plt.title('D={};L={}'.format(st["D"], st["L"]))
plt.ylabel("$S(E)$")
plt.xlabel("E")
#plt.ylim([-20, 0])
#plt.xlim([1200, 1300])
#plt.xlim([-2000, 2000])
plt.legend()
plt.grid()
#plt.savefig("./culling_factor_D{}_L{}.png".format(heat["D"], heat["L"]))

# %%
i = 0
heat, cool, st = parametersAR[i]["heat"], parametersAR[i]["cool"], parametersAR[i]["stitched"]

plt.figure(figsize=(16, 9))

plt.plot([E for E in heat["S"]],
         [S + 20 for E, S in heat["S"].items()]
         , 'o', label="heat, L={}".format(cool["L"]), markersize=2)

plt.plot([E for E in cool["S"]],
         [S + 20 for E, S in cool["S"].items()]
         , 'o', label="cool, L={}".format(cool["L"]), markersize=2)

plt.plot([E for E in st["S"]],
         [S for E, S in st["S"].items()]
         , 'o', label="stitched, L={}".format(st["L"]), markersize=2)

plt.ylabel("$S(E)$")
plt.xlabel("E")

plt.title('D={}'.format(st["D"]))
plt.legend()
plt.grid()
#plt.savefig("./S_stitched(E)_D{}_L{}.png".format(heat["D"], heat["L"]))

# %%
i = 0
tmp = sorted([(x, parameters[i]['stitched']['S'][x]) for x in parameters[i]['stitched']['S']], key=lambda x: x[0])
tmp_bin = {}
for i in range(0, len(tmp) - 1):
    x = (tmp[i + 1][0] - tmp[i][0])
    #if (x < 0.0001):
    #    print(tmp[i + 1][0], tmp[i][0], tmp[i + 1][0] - tmp[i][0])
    #tmp_bin.append(x)
    if x in tmp_bin:
        tmp_bin[x] += 1
    else:
        tmp_bin[x] = 1

plt.figure(figsize=(16, 9))

plt.plot([x for x in tmp_bin], [tmp_bin[x] for x in tmp_bin], 'o')
#plt.hist(tmp_bin, bins=100)

plt.ylabel("$n$")
plt.yscale('log')
plt.xscale('log')
plt.xlabel("$E_{i+1} - E_i$")
plt.grid()
#plt.savefig("./bin_D{}_L{}.png".format(heat["D"], heat["L"]))

# %%
plt.figure(figsize=(16, 9))

plt.scatter([tmp[i][0] for i in range(0, len(tmp) - 1)],
         [tmp[i+1][1]-tmp[i][1] for i in range(0, len(tmp) - 1)],
         label="D={}, L={}".format(st["D"], st["L"]), s=10)

plt.ylabel("$dS(E)$")
plt.xlabel("E")

plt.legend()
plt.grid()

# %%
i = 0
tmp = sorted([(x, parametersAR[i]['stitched']['S'][x]) for x in parametersAR[i]['stitched']['S']], key=lambda x: x[0])
tmp_bin = {}
for i in range(0, len(tmp) - 1):
    x = (tmp[i + 1][0] - tmp[i][0])
    #if (x < 0.0001):
    #    print(tmp[i + 1][0], tmp[i][0], tmp[i + 1][0] - tmp[i][0])
    #tmp_bin.append(x)
    if x in tmp_bin:
        tmp_bin[x] += 1
    else:
        tmp_bin[x] = 1

plt.figure(figsize=(16, 9))

plt.plot([x for x in tmp_bin], [tmp_bin[x] for x in tmp_bin], 'o')
#plt.hist(tmp_bin, bins=100)

plt.ylabel("$n$")
plt.yscale('log')
plt.xscale('log')
plt.xlabel("$E_{i+1} - E_i$")
plt.grid()
#plt.savefig("./bin_D{}_L{}.png".format(heat["D"], heat["L"]))

# %%
plt.figure(figsize=(16, 9))

plt.scatter([tmp[i][0] for i in range(0, len(tmp) - 1)],
         [tmp[i+1][1]-tmp[i][1] for i in range(0, len(tmp) - 1)],
         label="D={}, L={}".format(st["D"], st["L"]), s=10)

plt.ylabel("$dS(E)$")
plt.xlabel("E")

plt.legend()
plt.grid()
#plt.savefig("./dS(E)_D{}_L{}.png".format(heat["D"], heat["L"]))

# %%
import mpmath as mp
mp.mp.dps = 50
mp.mp.pretty = True
print(mp.mp)
# Out:
# Mpmath settings:
#   mp.prec = 169               [default: 53]
#   mp.dps = 50                 [default: 15]
#   mp.trap_complex = False     [default: False]

# %%
plt.figure(figsize=(16, 9))

for T in log_progress([0.4, 0.5, 0.55, 0.6, 0.65, 0.7]):
    for i, x in enumerate(parameters):
        heat, cool, st = parameters[i]["heat"], parameters[i]["cool"], parameters[i]["stitched"]
        D = st['D']
        L = st['L']
        if L != 32:
            continue
        lst = np.array([mp.exp(mp.mpf(S) - mp.mpf(E) / T) / Z for E, S in st["S"].items()])
        Z = sum(lst)
        plt.plot([E / (L * L) for E in st["S"]],
                 lst / Z
                 , 'o', label="stitched, T={}, L={}".format(T, L))

plt.ylabel('$P(E) = e^{S(E) - E / T} / Z$')
plt.xlabel("E")
plt.xlim([0, 0.5])
plt.title("D={}".format(D))
plt.legend()
plt.grid()
plt.savefig("./P(E)_D{}_L{}.png".format(heat["D"], heat["L"]))

# %%
def calc_hc(st, T):
    E = mp.mpf(0)
    E_sq = mp.mpf(0)
    Z = mp.mpf(0)
    for fe, fS in st['S'].items():
        e = mp.mpf(fe)
        S = mp.mpf(fS)
        w = mp.exp(S - e / T)
        Z += w
        E += w * e
        E_sq += w * e * e
    avgE = E / Z;
    avgE_sq = E_sq / Z;
    return (avgE_sq - avgE * avgE) / (T * T)

# %%
hc = {}

for i, x in enumerate(parameters):
    heat, cool, st = parameters[i]["heat"], parameters[i]["cool"], parameters[i]["stitched"]
    L = st['L']
    N = L * L
    hc[L] = {}
    for T in log_progress(np.linspace(0.4, 2.0, 20)):
        hc[L][T] = calc_hc(st, T)

# %%
a = 0.4
b = 4.0

# %%
for i, x in enumerate(parameters):
    heat, cool, st = parameters[i]["heat"], parameters[i]["cool"], parameters[i]["stitched"]
    L = st['L']
    N = L * L
    for T in log_progress(np.linspace(a, b, 20)):
        hc[L][T] = calc_hc(st, T)

# %%
T_crit = {}
for i, x in enumerate(parameters):
    st = x["stitched"]
    L = st["L"]
    t, c, _, _ = fminbound(lambda T: - calc_hc(st, T), a, b, maxfun=500, full_output=1, disp=2)
    T_crit[L] = {
        "T_crit": float(t),
        "C_crit": float(-c / (L * L))
    }
T_crit

# %%
D = 1.0

# %%
T_crit

# %%
with open("./tmp/T_crit_D{}.txt".format(D), 'w') as fp:
    json.dump(T_crit, fp)

# %%
#D = heat["D"]

# %%
with open("./tmp/T_crit_D{}.txt".format(D), 'r') as fp:
    T_crit = json.load(fp)
T_crit

# %%
plt.figure(figsize=(16, 9))

for L in T_crit:
    plt.scatter(T_crit[L]['T_crit'], T_crit[L]['C_crit'] / (int(L) * int(L)), label='L={};'.format(L))

    
#plt.plot([Tc, Tc], [0, 3300], label='Tc_their={}'.format(Tc), c='r')
#for L, data in T_crit.items():
#    plt.plot([data['T_crit'], data['T_crit']], [0, 5], label='T_crit_our={:.4f}'.format(float(data['T_crit'])), c='r')

#plt.yscale("log")
plt.title("D={}".format(D))
plt.ylabel('$C(T) / N$')
plt.xlabel("T")
plt.legend()
plt.grid()
#plt.savefig("./C(T)_D{}_L{}.png".format(heat["D"], heat["L"]))
plt.savefig("./C(T)_D{}.png".format(D))

# %%
x = np.array([int(L) for L in T_crit.keys()])
y = np.array([T_crit[L]['T_crit'] for L in T_crit.keys()])
z = np.array([T_crit[L]['C_crit'] / (int(L) * int(L)) for L in T_crit.keys()])

# %%
l = 3
fit = np.polyfit(1 / x[l:], list(map(float, y[l:])), 1, full=False)

plt.figure(figsize=(16, 9))

plt.scatter(1 / x, y)

sample = np.array([0, 0.2])
plt.plot(sample, fit[0] * sample + fit[1], 'r')

plt.title("D={}".format(D))
plt.ylabel('$T_{crit}$')
plt.xlabel("1/L")
#plt.yscale("log")
plt.grid()
plt.legend()
plt.savefig("./finite_size_D{}.png".format(D))

p, V = np.polyfit(1 / x[l:], list(map(float, y[l:])), 1, cov=True)

print("slope: \t{} +/-\n\t{}".format(p[0], np.sqrt(V[0][0])))
print("shift: \t{} +/-\n\t{}".format(p[1], np.sqrt(V[1][1])))

# %%
#np.polyfit(x[1:], list(map(float, y[1:])), 1, full=True)

# %%
plt.scatter(np.log(x), z)

sample = np.array([0, 0.2])
#plt.plot(sample, fit[0] * sample + fit[1], 'r')

plt.title("D={}".format(cool["D"]))
plt.ylabel('$С_{crit} / N$')
plt.xlabel("ln L")
#plt.yscale("log")
plt.legend()
plt.grid()

# %%
hc = {}
E = {}
BC = {}

# %%
for i, x in enumerate(parameters):
    heat, cool, st = parameters[i]["heat"], parameters[i]["cool"], parameters[i]["stitched"]
    L = st['L']
    N = L * L

    hc[L] = {}
    E[L] = {}
    BC[L] = {}

# %%
frames_list = list(zip(itertools.repeat(st), [x for x in np.linspace(0.3, 0.6, 20) if x not in hc[L]]))

with Pool(3) as p:
    pool_outputs = list(
            p.map(calc_hc_tpl, tqdm(frames_list, total=len(frames_list)))
    )

# T, C, average E, BinderCumulant
for tpl in pool_outputs:
    T, x, y, z = tpl
    hc[L][T], E[L][T], BC[L][T] = x, y, z
# Out:
# HBox(children=(IntProgress(value=0, max=18), HTML(value='')))

# %%
plt.figure(figsize=(16, 9))


plt.plot([float(T) for T in hc[st["L"]]], [c for T, c in hc[st["L"]].items()], 'o', markerSize = 4)
plt.grid()
plt.title("$D={}$".format(st["D"]), fontsize=16)
plt.ylabel('$BC$', fontsize=16)
plt.xlabel('$T$', fontsize=16)
plt.show()

# %%
from itertools import cycle

# %%
i = 0
for L in [32]:
    for D_div, D_base in [(0, 1), (5, 10), (1, 1), (15, 10), (175, 100), (187, 100), (19, 10), (192, 100), (195, 100), (1962, 1000), (199, 100)]:
        for heat in [0, 1]:
            for seed in [1, 2, 3, 4, 5, 6, 7, 8, 9]:
                print('{}) heat={}; L={}; D_div={}; D_base={}; seed={};;'.format(i, heat, L, D_div, D_base, seed))
                i+=1
# Out:
# 0) heat=0; L=32; D_div=0; D_base=1; seed=1;;
# 1) heat=0; L=32; D_div=0; D_base=1; seed=2;;
# 2) heat=0; L=32; D_div=0; D_base=1; seed=3;;
# 3) heat=0; L=32; D_div=0; D_base=1; seed=4;;
# 4) heat=0; L=32; D_div=0; D_base=1; seed=5;;
# 5) heat=0; L=32; D_div=0; D_base=1; seed=6;;
# 6) heat=0; L=32; D_div=0; D_base=1; seed=7;;
# 7) heat=0; L=32; D_div=0; D_base=1; seed=8;;
# 8) heat=0; L=32; D_div=0; D_base=1; seed=9;;
# 9) heat=1; L=32; D_div=0; D_base=1; seed=1;;
# 10) heat=1; L=32; D_div=0; D_base=1; seed=2;;
# 11) heat=1; L=32; D_div=0; D_base=1; seed=3;;
# 12) heat=1; L=32; D_div=0; D_base=1; seed=4;;
# 13) heat=1; L=32; D_div=0; D_base=1; seed=5;;
# 14) heat=1; L=32; D_div=0; D_base=1; seed=6;;
# 15) heat=1; L=32; D_div=0; D_base=1; seed=7;;
# 16) heat=1; L=32; D_div=0; D_base=1; seed=8;;
# 17) heat=1; L=32; D_div=0; D_base=1; seed=9;;
# 18) heat=0; L=32; D_div=5; D_base=10; seed=1;;
# 19) heat=0; L=32; D_div=5; D_base=10; seed=2;;
# 20) heat=0; L=32; D_div=5; D_base=10; seed=3;;
# 21) heat=0; L=32; D_div=5; D_base=10; seed=4;;
# 22) heat=0; L=32; D_div=5; D_base=10; seed=5;;
# 23) heat=0; L=32; D_div=5; D_base=10; seed=6;;
# 24) heat=0; L=32; D_div=5; D_base=10; seed=7;;
# 25) heat=0; L=32; D_div=5; D_base=10; seed=8;;
# 26) heat=0; L=32; D_div=5; D_base=10; seed=9;;
# 27) heat=1; L=32; D_div=5; D_base=10; seed=1;;
# 28) heat=1; L=32; D_div=5; D_base=10; seed=2;;
# 29) heat=1; L=32; D_div=5; D_base=10; seed=3;;
# 30) heat=1; L=32; D_div=5; D_base=10; seed=4;;
# 31) heat=1; L=32; D_div=5; D_base=10; seed=5;;
# 32) heat=1; L=32; D_div=5; D_base=10; seed=6;;
# 33) heat=1; L=32; D_div=5; D_base=10; seed=7;;
# 34) heat=1; L=32; D_div=5; D_base=10; seed=8;;
# 35) heat=1; L=32; D_div=5; D_base=10; seed=9;;
# 36) heat=0; L=32; D_div=1; D_base=1; seed=1;;
# 37) heat=0; L=32; D_div=1; D_base=1; seed=2;;
# 38) heat=0; L=32; D_div=1; D_base=1; seed=3;;
# 39) heat=0; L=32; D_div=1; D_base=1; seed=4;;
# 40) heat=0; L=32; D_div=1; D_base=1; seed=5;;
# 41) heat=0; L=32; D_div=1; D_base=1; seed=6;;
# 42) heat=0; L=32; D_div=1; D_base=1; seed=7;;
# 43) heat=0; L=32; D_div=1; D_base=1; seed=8;;
# 44) heat=0; L=32; D_div=1; D_base=1; seed=9;;
# 45) heat=1; L=32; D_div=1; D_base=1; seed=1;;
# 46) heat=1; L=32; D_div=1; D_base=1; seed=2;;
# 47) heat=1; L=32; D_div=1; D_base=1; seed=3;;
# 48) heat=1; L=32; D_div=1; D_base=1; seed=4;;
# 49) heat=1; L=32; D_div=1; D_base=1; seed=5;;
# 50) heat=1; L=32; D_div=1; D_base=1; seed=6;;
# 51) heat=1; L=32; D_div=1; D_base=1; seed=7;;
# 52) heat=1; L=32; D_div=1; D_base=1; seed=8;;
# 53) heat=1; L=32; D_div=1; D_base=1; seed=9;;
# 54) heat=0; L=32; D_div=15; D_base=10; seed=1;;
# 55) heat=0; L=32; D_div=15; D_base=10; seed=2;;
# 56) heat=0; L=32; D_div=15; D_base=10; seed=3;;
# 57) heat=0; L=32; D_div=15; D_base=10; seed=4;;
# 58) heat=0; L=32; D_div=15; D_base=10; seed=5;;
# 59) heat=0; L=32; D_div=15; D_base=10; seed=6;;
# 60) heat=0; L=32; D_div=15; D_base=10; seed=7;;
# 61) heat=0; L=32; D_div=15; D_base=10; seed=8;;
# 62) heat=0; L=32; D_div=15; D_base=10; seed=9;;
# 63) heat=1; L=32; D_div=15; D_base=10; seed=1;;
# 64) heat=1; L=32; D_div=15; D_base=10; seed=2;;
# 65) heat=1; L=32; D_div=15; D_base=10; seed=3;;
# 66) heat=1; L=32; D_div=15; D_base=10; seed=4;;
# 67) heat=1; L=32; D_div=15; D_base=10; seed=5;;
# 68) heat=1; L=32; D_div=15; D_base=10; seed=6;;
# 69) heat=1; L=32; D_div=15; D_base=10; seed=7;;
# 70) heat=1; L=32; D_div=15; D_base=10; seed=8;;
# 71) heat=1; L=32; D_div=15; D_base=10; seed=9;;
# 72) heat=0; L=32; D_div=175; D_base=100; seed=1;;
# 73) heat=0; L=32; D_div=175; D_base=100; seed=2;;
# 74) heat=0; L=32; D_div=175; D_base=100; seed=3;;
# 75) heat=0; L=32; D_div=175; D_base=100; seed=4;;
# 76) heat=0; L=32; D_div=175; D_base=100; seed=5;;
# 77) heat=0; L=32; D_div=175; D_base=100; seed=6;;
# 78) heat=0; L=32; D_div=175; D_base=100; seed=7;;
# 79) heat=0; L=32; D_div=175; D_base=100; seed=8;;
# 80) heat=0; L=32; D_div=175; D_base=100; seed=9;;
# 81) heat=1; L=32; D_div=175; D_base=100; seed=1;;
# 82) heat=1; L=32; D_div=175; D_base=100; seed=2;;
# 83) heat=1; L=32; D_div=175; D_base=100; seed=3;;
# 84) heat=1; L=32; D_div=175; D_base=100; seed=4;;
# 85) heat=1; L=32; D_div=175; D_base=100; seed=5;;
# 86) heat=1; L=32; D_div=175; D_base=100; seed=6;;
# 87) heat=1; L=32; D_div=175; D_base=100; seed=7;;
# 88) heat=1; L=32; D_div=175; D_base=100; seed=8;;
# 89) heat=1; L=32; D_div=175; D_base=100; seed=9;;
# 90) heat=0; L=32; D_div=187; D_base=100; seed=1;;
# 91) heat=0; L=32; D_div=187; D_base=100; seed=2;;
# 92) heat=0; L=32; D_div=187; D_base=100; seed=3;;
# 93) heat=0; L=32; D_div=187; D_base=100; seed=4;;
# 94) heat=0; L=32; D_div=187; D_base=100; seed=5;;
# 95) heat=0; L=32; D_div=187; D_base=100; seed=6;;
# 96) heat=0; L=32; D_div=187; D_base=100; seed=7;;
# 97) heat=0; L=32; D_div=187; D_base=100; seed=8;;
# 98) heat=0; L=32; D_div=187; D_base=100; seed=9;;
# 99) heat=1; L=32; D_div=187; D_base=100; seed=1;;
# 100) heat=1; L=32; D_div=187; D_base=100; seed=2;;
# 101) heat=1; L=32; D_div=187; D_base=100; seed=3;;
# 102) heat=1; L=32; D_div=187; D_base=100; seed=4;;
# 103) heat=1; L=32; D_div=187; D_base=100; seed=5;;
# 104) heat=1; L=32; D_div=187; D_base=100; seed=6;;
# 105) heat=1; L=32; D_div=187; D_base=100; seed=7;;
# 106) heat=1; L=32; D_div=187; D_base=100; seed=8;;
# 107) heat=1; L=32; D_div=187; D_base=100; seed=9;;
# 108) heat=0; L=32; D_div=19; D_base=10; seed=1;;
# 109) heat=0; L=32; D_div=19; D_base=10; seed=2;;
# 110) heat=0; L=32; D_div=19; D_base=10; seed=3;;
# 111) heat=0; L=32; D_div=19; D_base=10; seed=4;;
# 112) heat=0; L=32; D_div=19; D_base=10; seed=5;;
# 113) heat=0; L=32; D_div=19; D_base=10; seed=6;;
# 114) heat=0; L=32; D_div=19; D_base=10; seed=7;;
# 115) heat=0; L=32; D_div=19; D_base=10; seed=8;;
# 116) heat=0; L=32; D_div=19; D_base=10; seed=9;;
# 117) heat=1; L=32; D_div=19; D_base=10; seed=1;;
# 118) heat=1; L=32; D_div=19; D_base=10; seed=2;;
# 119) heat=1; L=32; D_div=19; D_base=10; seed=3;;
# 120) heat=1; L=32; D_div=19; D_base=10; seed=4;;
# 121) heat=1; L=32; D_div=19; D_base=10; seed=5;;
# 122) heat=1; L=32; D_div=19; D_base=10; seed=6;;
# 123) heat=1; L=32; D_div=19; D_base=10; seed=7;;
# 124) heat=1; L=32; D_div=19; D_base=10; seed=8;;
# 125) heat=1; L=32; D_div=19; D_base=10; seed=9;;
# 126) heat=0; L=32; D_div=192; D_base=100; seed=1;;
# 127) heat=0; L=32; D_div=192; D_base=100; seed=2;;
# 128) heat=0; L=32; D_div=192; D_base=100; seed=3;;
# 129) heat=0; L=32; D_div=192; D_base=100; seed=4;;
# 130) heat=0; L=32; D_div=192; D_base=100; seed=5;;
# 131) heat=0; L=32; D_div=192; D_base=100; seed=6;;
# 132) heat=0; L=32; D_div=192; D_base=100; seed=7;;
# 133) heat=0; L=32; D_div=192; D_base=100; seed=8;;
# 134) heat=0; L=32; D_div=192; D_base=100; seed=9;;
# 135) heat=1; L=32; D_div=192; D_base=100; seed=1;;
# 136) heat=1; L=32; D_div=192; D_base=100; seed=2;;
# 137) heat=1; L=32; D_div=192; D_base=100; seed=3;;
# 138) heat=1; L=32; D_div=192; D_base=100; seed=4;;
# 139) heat=1; L=32; D_div=192; D_base=100; seed=5;;
# 140) heat=1; L=32; D_div=192; D_base=100; seed=6;;
# 141) heat=1; L=32; D_div=192; D_base=100; seed=7;;
# 142) heat=1; L=32; D_div=192; D_base=100; seed=8;;
# 143) heat=1; L=32; D_div=192; D_base=100; seed=9;;
# 144) heat=0; L=32; D_div=195; D_base=100; seed=1;;
# 145) heat=0; L=32; D_div=195; D_base=100; seed=2;;
# 146) heat=0; L=32; D_div=195; D_base=100; seed=3;;
# 147) heat=0; L=32; D_div=195; D_base=100; seed=4;;
# 148) heat=0; L=32; D_div=195; D_base=100; seed=5;;
# 149) heat=0; L=32; D_div=195; D_base=100; seed=6;;
# 150) heat=0; L=32; D_div=195; D_base=100; seed=7;;
# 151) heat=0; L=32; D_div=195; D_base=100; seed=8;;
# 152) heat=0; L=32; D_div=195; D_base=100; seed=9;;
# 153) heat=1; L=32; D_div=195; D_base=100; seed=1;;
# 154) heat=1; L=32; D_div=195; D_base=100; seed=2;;
# 155) heat=1; L=32; D_div=195; D_base=100; seed=3;;
# 156) heat=1; L=32; D_div=195; D_base=100; seed=4;;
# 157) heat=1; L=32; D_div=195; D_base=100; seed=5;;
# 158) heat=1; L=32; D_div=195; D_base=100; seed=6;;
# 159) heat=1; L=32; D_div=195; D_base=100; seed=7;;
# 160) heat=1; L=32; D_div=195; D_base=100; seed=8;;
# 161) heat=1; L=32; D_div=195; D_base=100; seed=9;;
# 162) heat=0; L=32; D_div=1962; D_base=1000; seed=1;;
# 163) heat=0; L=32; D_div=1962; D_base=1000; seed=2;;
# 164) heat=0; L=32; D_div=1962; D_base=1000; seed=3;;
# 165) heat=0; L=32; D_div=1962; D_base=1000; seed=4;;
# 166) heat=0; L=32; D_div=1962; D_base=1000; seed=5;;
# 167) heat=0; L=32; D_div=1962; D_base=1000; seed=6;;
# 168) heat=0; L=32; D_div=1962; D_base=1000; seed=7;;
# 169) heat=0; L=32; D_div=1962; D_base=1000; seed=8;;
# 170) heat=0; L=32; D_div=1962; D_base=1000; seed=9;;
# 171) heat=1; L=32; D_div=1962; D_base=1000; seed=1;;
# 172) heat=1; L=32; D_div=1962; D_base=1000; seed=2;;
# 173) heat=1; L=32; D_div=1962; D_base=1000; seed=3;;
# 174) heat=1; L=32; D_div=1962; D_base=1000; seed=4;;
# 175) heat=1; L=32; D_div=1962; D_base=1000; seed=5;;
# 176) heat=1; L=32; D_div=1962; D_base=1000; seed=6;;
# 177) heat=1; L=32; D_div=1962; D_base=1000; seed=7;;
# 178) heat=1; L=32; D_div=1962; D_base=1000; seed=8;;
# 179) heat=1; L=32; D_div=1962; D_base=1000; seed=9;;
# 180) heat=0; L=32; D_div=199; D_base=100; seed=1;;
# 181) heat=0; L=32; D_div=199; D_base=100; seed=2;;
# 182) heat=0; L=32; D_div=199; D_base=100; seed=3;;
# 183) heat=0; L=32; D_div=199; D_base=100; seed=4;;
# 184) heat=0; L=32; D_div=199; D_base=100; seed=5;;
# 185) heat=0; L=32; D_div=199; D_base=100; seed=6;;
# 186) heat=0; L=32; D_div=199; D_base=100; seed=7;;
# 187) heat=0; L=32; D_div=199; D_base=100; seed=8;;
# 188) heat=0; L=32; D_div=199; D_base=100; seed=9;;
# 189) heat=1; L=32; D_div=199; D_base=100; seed=1;;
# 190) heat=1; L=32; D_div=199; D_base=100; seed=2;;
# 191) heat=1; L=32; D_div=199; D_base=100; seed=3;;
# 192) heat=1; L=32; D_div=199; D_base=100; seed=4;;
# 193) heat=1; L=32; D_div=199; D_base=100; seed=5;;
# 194) heat=1; L=32; D_div=199; D_base=100; seed=6;;
# 195) heat=1; L=32; D_div=199; D_base=100; seed=7;;
# 196) heat=1; L=32; D_div=199; D_base=100; seed=8;;
# 197) heat=1; L=32; D_div=199; D_base=100; seed=9;;
